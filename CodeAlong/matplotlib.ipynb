# %% [markdown]
# # Matplotlib
# - [Grafräknare Online](desmos.com)
# -

# %%
import matplotlib.pyplot as plt

x = list(range(-10,11))

y = [value**2 for value in x]
y2 = [value**3 for value in x]

plt.plot(x, y)
plt.plot(x, y2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\danie\Documents\GitHUb\Python_Daniel_Claesson\CodeAlong\matplotlib.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/GitHUb/Python_Daniel_Claesson/CodeAlong/matplotlib.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/GitHUb/Python_Daniel_Claesson/CodeAlong/matplotlib.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> x = list(range(-10,11))
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/GitHUb/Python_Daniel_Claesson/CodeAlong/matplotlib.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> y = [value**2 for value in x]
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
x = [0, -100, 25, 65, -323]
y = [0, 3, 7, 3, 9]

plt.title("My Graph")
plt.xlabel("X-values")
plt.ylabel("Y-values")
plt.grid()
#plt.axis([-50, 80, 2, 8])
plt.plot(x, y, color="red", linestyle="dashed", marker='o')

# %% [markdown]
# ## Scatter plot

# %%
x = list(range(-10,11))
y = x

plt.scatter(x, y, marker="o")

# %% [markdown]
# ## Bar plots

# %%
labels = ["Male", "Female"]
values = [15, 23]

plt.bar(labels, values)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ## Pie Charts

# %%
plt.pie(values, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x20742289670>,
#   <matplotlib.patches.Wedge at 0x20742289580>],
#  [Text(0.3571693699839605, 1.040398981710988, 'Male'),
#   Text(-0.357169272574776, -1.0403990151515934, 'Female')])

# %%
## Subplots

x = list(range(-10,11))
y = [value**2 for value in x]
y2 = [value**3 for value in x]

fig, axs = plt.subplots(1, 2)
axs[0].plot(x, y)
axs[1].plot(x, y2)
fig.set_facecolor("red")
axs[1].set_facecolor("blue")
